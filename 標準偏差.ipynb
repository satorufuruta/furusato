# %%
import os
os.getcwd()
# Out:
# '/Users/furutasatoru/Documents/GitHub'

# %%
os.chdir('/Users/furutasatoru/Documents/大学/シス創/大規模データ分析/new_ingredient')

# %%
import pandas as pd
df_rate = pd.read_csv("ingredient_rate.csv", index_col=0)
df_rate
# Out:
#                             1998      1999      2000      2001      2002  \
# 砂糖                      0.162791  0.186969  0.252723  0.316490  0.294252
# 塩                       0.302326  0.218130  0.302067  0.295750  0.293566
# 水                       0.046512  0.082153  0.111136  0.137454  0.146135
# 卵                       0.255814  0.138810  0.196266  0.188186  0.184708
# 醤油                      0.302326  0.167139  0.134030  0.144774  0.131804
# 酒                       0.116279  0.110482  0.124250  0.147418  0.127840
# 塩コショウ                   0.000000  0.031161  0.071127  0.083876  0.083397
# 牛乳                      0.209302  0.104816  0.119582  0.120679  0.128754
# バター                     0.186047  0.127479  0.147366  0.142843  0.154444
# 玉ネギ                     0.023256  0.065156  0.079351  0.073709  0.077527
# ミリン                     0.046512  0.076487  0.074461  0.089162  0.083244
# ゴマ油                     0.023256  0.079320  0.086241  0.087739  0.087894
# ...

# %%
import numpy as np
cols = ['1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','標準偏差']
df_rate_std = pd.DataFrame(index=[], columns=cols)
for i in range(0,len(df_rate)):
    df_rate_std.loc[df_rate.index[i]] = np.append(np.array(df_rate.iloc[i]),np.std(np.array(df_rate.iloc[i])))
df_rate_std
# Out:
#                             1998      1999      2000      2001      2002  \
# 砂糖                      0.162791  0.186969  0.252723  0.316490  0.294252
# 塩                       0.302326  0.218130  0.302067  0.295750  0.293566
# 水                       0.046512  0.082153  0.111136  0.137454  0.146135
# 卵                       0.255814  0.138810  0.196266  0.188186  0.184708
# 醤油                      0.302326  0.167139  0.134030  0.144774  0.131804
# 酒                       0.116279  0.110482  0.124250  0.147418  0.127840
# 塩コショウ                   0.000000  0.031161  0.071127  0.083876  0.083397
# 牛乳                      0.209302  0.104816  0.119582  0.120679  0.128754
# バター                     0.186047  0.127479  0.147366  0.142843  0.154444
# 玉ネギ                     0.023256  0.065156  0.079351  0.073709  0.077527
# ミリン                     0.046512  0.076487  0.074461  0.089162  0.083244
# ゴマ油                     0.023256  0.079320  0.086241  0.087739  0.087894
# ...

# %%
df_rate_std = df_rate_std.sort_values('標準偏差',ascending=False)
df_rate_std
# Out:
#                       1998      1999      2000      2001      2002      2003  \
# 砂糖                0.162791  0.186969  0.252723  0.316490  0.294252  0.297201
# 塩                 0.302326  0.218130  0.302067  0.295750  0.293566  0.282932
# 水                 0.046512  0.082153  0.111136  0.137454  0.146135  0.157312
# 醤油                0.302326  0.167139  0.134030  0.144774  0.131804  0.141942
# タマネギ              0.186047  0.059490  0.068460  0.050630  0.057250  0.053372
# コショウ              0.116279  0.090652  0.128473  0.094347  0.087971  0.080809
# 塩コショウ             0.000000  0.031161  0.071127  0.083876  0.083397  0.082311
# 卵                 0.255814  0.138810  0.196266  0.188186  0.184708  0.196015
# NaN               0.000000  0.000000  0.000667  0.007930  0.014255  0.013218
# ショウユ              0.000000  0.099150  0.110691  0.100549  0.109697  0.101387
# バター               0.186047  0.127479  0.147366  0.142843  0.154444  0.145597
# ...

# %%
df_rate_std.index[1]
# Out:
# '塩'

# %%
for i in range(0,50):
    print(df_rate_std.index[i])
# Out:
# 砂糖
# 塩
# 水
# 醤油
# タマネギ
# コショウ
# 塩コショウ
# 卵
# nan
# ショウユ
# バター
# 薄力粉
# 牛乳
# 生クリーム
# ショウガ
# ニンジン
# ゴマアブラ
# 紅茶
# 玉ネギ
# ニンニク
# 人参
# サラダ油
# ダシ汁
# ナス
# ハチミツ
# 生トマト
# ハーブ
# 長ネギ
# マヨネーズ
# 白米
# 赤ピーマン
# ゴマ油
# レモン
# サラダオイル
# 熱湯
# オリーブオイル
# ピーマン
# 小麦粉
# ベーキングパウダー
# 大葉
# 胡椒
# ジャガイモ
# 卵黄
# 豚肉
# 片栗粉
# グラニュー糖
# ミリン
# ダイコン
# 酒
# グランマニエ

# %%
print(df_rate_std.loc['オリーブオイル'])
# Out:
# 1998    0.116279
# 1999    0.082153
# 2000    0.063347
# 2001    0.054290
# 2002    0.065711
# 2003    0.056677
# 2004    0.063008
# 2005    0.062728
# 2006    0.056448
# 2007    0.059491
# 2008    0.061635
# 2009    0.066701
# 2010    0.076022
# 2011    0.074652
# 2012    0.080473
# 2013    0.087385
# 2014    0.087401
# 標準偏差    0.015322
# Name: オリーブオイル, dtype: float64

# %%
print(df_rate_std.loc['アボカド'])
# Out:
# 1998    0.000000
# 1999    0.000000
# 2000    0.002000
# 2001    0.002948
# 2002    0.004726
# 2003    0.005708
# 2004    0.006305
# 2005    0.007407
# 2006    0.008515
# 2007    0.008742
# 2008    0.007328
# 2009    0.008041
# 2010    0.011465
# 2011    0.009520
# 2012    0.013787
# 2013    0.013675
# 2014    0.012685
# 標準偏差    0.004213
# Name: アボカド, dtype: float64

# %%
print(df_rate_std.loc['パクチー'])
# Out:
# 1998    0.000000
# 1999    0.002833
# 2000    0.001334
# 2001    0.000610
# 2002    0.000152
# 2003    0.000701
# 2004    0.000514
# 2005    0.001004
# 2006    0.000932
# 2007    0.000917
# 2008    0.000740
# 2009    0.000754
# 2010    0.000793
# 2011    0.000929
# 2012    0.001067
# 2013    0.001164
# 2014    0.001716
# 標準偏差    0.000611
# Name: パクチー, dtype: float64

# %%
print(df_rate_std.loc['ナタデココ'])
# Out:
# 1998    0.000000
# 1999    0.000000
# 2000    0.000000
# 2001    0.000000
# 2002    0.000000
# 2003    0.000100
# 2004    0.000093
# 2005    0.000167
# 2006    0.000191
# 2007    0.000122
# 2008    0.000090
# 2009    0.000093
# 2010    0.000109
# 2011    0.000085
# 2012    0.000111
# 2013    0.000110
# 2014    0.000118
# 標準偏差    0.000059
# Name: ナタデココ, dtype: float64

# %%
df_rate_change = df_rate.pct_change(axis=1)
df_rate_change
# Out:
#                         1998      1999      2000       2001      2002  \
# 砂糖                       NaN  0.148523  0.351684   0.252322 -0.070265
# 塩                        NaN -0.278492  0.384801  -0.020912 -0.007385
# 水                        NaN  0.766289  0.352791   0.236813  0.063154
# 卵                        NaN -0.457378  0.413915  -0.041167 -0.018483
# 醤油                       NaN -0.447156 -0.198093   0.080165 -0.089592
# 酒                        NaN -0.049858  0.124620   0.186462 -0.132807
# 塩コショウ                    NaN       inf  1.282527   0.179238 -0.005707
# 牛乳                       NaN -0.499213  0.140878   0.009174  0.066915
# バター                      NaN -0.314802  0.156005  -0.030695  0.081220
# 玉ネギ                      NaN  1.801700  0.217865  -0.071104  0.051802
# ミリン                      NaN  0.644476 -0.026491   0.197436 -0.066372
# ゴマ油                      NaN  2.410765  0.087257   0.017364  0.001773
# ...

# %%
df_rate
# Out:
#                             1998      1999      2000      2001      2002  \
# 砂糖                      0.162791  0.186969  0.252723  0.316490  0.294252
# 塩                       0.302326  0.218130  0.302067  0.295750  0.293566
# 水                       0.046512  0.082153  0.111136  0.137454  0.146135
# 卵                       0.255814  0.138810  0.196266  0.188186  0.184708
# 醤油                      0.302326  0.167139  0.134030  0.144774  0.131804
# 酒                       0.116279  0.110482  0.124250  0.147418  0.127840
# 塩コショウ                   0.000000  0.031161  0.071127  0.083876  0.083397
# 牛乳                      0.209302  0.104816  0.119582  0.120679  0.128754
# バター                     0.186047  0.127479  0.147366  0.142843  0.154444
# 玉ネギ                     0.023256  0.065156  0.079351  0.073709  0.077527
# ミリン                     0.046512  0.076487  0.074461  0.089162  0.083244
# ゴマ油                     0.023256  0.079320  0.086241  0.087739  0.087894
# ...

# %%
cols = ['1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','標準偏差']
df_rate_ave = pd.DataFrame(index=[], columns=cols)
for i in range(0,len(df_rate)):
    df_rate_ave.loc[df_rate.index[i]] = np.append(np.array(df_rate.iloc[i]),np.mean(np.array(df_rate.iloc[i])))
df_rate_ave
# Out:
#                             1998      1999      2000      2001      2002  \
# 砂糖                      0.162791  0.186969  0.252723  0.316490  0.294252
# 塩                       0.302326  0.218130  0.302067  0.295750  0.293566
# 水                       0.046512  0.082153  0.111136  0.137454  0.146135
# 卵                       0.255814  0.138810  0.196266  0.188186  0.184708
# 醤油                      0.302326  0.167139  0.134030  0.144774  0.131804
# 酒                       0.116279  0.110482  0.124250  0.147418  0.127840
# 塩コショウ                   0.000000  0.031161  0.071127  0.083876  0.083397
# 牛乳                      0.209302  0.104816  0.119582  0.120679  0.128754
# バター                     0.186047  0.127479  0.147366  0.142843  0.154444
# 玉ネギ                     0.023256  0.065156  0.079351  0.073709  0.077527
# ミリン                     0.046512  0.076487  0.074461  0.089162  0.083244
# ゴマ油                     0.023256  0.079320  0.086241  0.087739  0.087894
# ...

# %%
df_rate_ave = df_rate_ave.sort_values('標準偏差',ascending=False)
df_rate_ave
# Out:
#                           1998      1999      2000      2001      2002  \
# 砂糖                    0.162791  0.186969  0.252723  0.316490  0.294252
# 塩                     0.302326  0.218130  0.302067  0.295750  0.293566
# 卵                     0.255814  0.138810  0.196266  0.188186  0.184708
# 水                     0.046512  0.082153  0.111136  0.137454  0.146135
# 醤油                    0.302326  0.167139  0.134030  0.144774  0.131804
# バター                   0.186047  0.127479  0.147366  0.142843  0.154444
# 酒                     0.116279  0.110482  0.124250  0.147418  0.127840
# 牛乳                    0.209302  0.104816  0.119582  0.120679  0.128754
# ニンニク                  0.093023  0.147309  0.135363  0.115494  0.125781
# 塩コショウ                 0.000000  0.031161  0.071127  0.083876  0.083397
# 玉ネギ                   0.023256  0.065156  0.079351  0.073709  0.077527
# ミリン                   0.046512  0.076487  0.074461  0.089162  0.083244
# ...

# %%
df_rate_ave = df_rate_ave.rename(columns={'標準偏差': 'average'})

# %%
df_rate_ave.head()
# Out:
#         1998      1999      2000      2001      2002      2003      2004  \
# 砂糖  0.162791  0.186969  0.252723  0.316490  0.294252  0.297201  0.331948
# 塩   0.302326  0.218130  0.302067  0.295750  0.293566  0.282932  0.277767
# 卵   0.255814  0.138810  0.196266  0.188186  0.184708  0.196015  0.199393
# 水   0.046512  0.082153  0.111136  0.137454  0.146135  0.157312  0.169687
# 醤油  0.302326  0.167139  0.134030  0.144774  0.131804  0.141942  0.134703
#
#         2005      2006      2007      2008      2009      2010      2011  \
# 砂糖  0.332050  0.301025  0.275402  0.270690  0.267375  0.259514  0.257500
# 塩   0.294514  0.208400  0.194871  0.207782  0.219195  0.219569  0.218201
# 卵   0.203331  0.185101  0.163768  0.157855  0.150742  0.147333  0.147046
# 水   0.178056  0.161082  0.163487  0.175764  0.186138  0.185114  0.195974
# 醤油  0.137005  0.130348  0.126385  0.131595  0.143562  0.147593  0.141466
#
#         2012      2013      2014   average
# 砂糖  0.249928  0.254404  0.242521  0.267811
# ...

# %%
df_rate_ave[df_rate_ave['average']>0.05].loc[:,['average']]
# Out:
#           average
# 砂糖       0.267811
# 塩        0.243856
# 卵        0.174127
# 水        0.157665
# 醤油       0.153127
# バター      0.125045
# 酒        0.123384
# 牛乳       0.120794
# ニンニク     0.101267
# 塩コショウ    0.092708
# 玉ネギ      0.085464
# ミリン      0.085075
# ゴマ油      0.083928
# ショウユ     0.078319
# オリーブオイル  0.071435
# 薄力粉      0.070843
# 小麦粉      0.069100
# マヨネーズ    0.069057
# サラダ油     0.064401
# ニンジン     0.060073
# コショウ     0.059655
# 生クリーム    0.058566
# 片栗粉      0.057318
# ジャガイモ    0.050876
# タマネギ     0.050749

# %%
df_rate.loc['アボカド'].pct_change()
# Out:
# 1998         NaN
# 1999         NaN
# 2000         inf
# 2001    0.473849
# 2002    0.603041
# 2003    0.207640
# 2004    0.104728
# 2005    0.174662
# 2006    0.149592
# 2007    0.026690
# 2008   -0.161739
# 2009    0.097345
# 2010    0.425785
# 2011   -0.169676
# 2012    0.448217
# 2013   -0.008117
# 2014   -0.072393
# Name: アボカド, dtype: float64

# %%
df_rate.loc['オリーブオイル'].pct_change()
# Out:
# 1998         NaN
# 1999   -0.293484
# 2000   -0.228909
# 2001   -0.142974
# 2002    0.210367
# 2003   -0.137491
# 2004    0.111712
# 2005   -0.004450
# 2006   -0.100116
# 2007    0.053914
# 2008    0.036042
# 2009    0.082187
# 2010    0.139742
# 2011   -0.018020
# 2012    0.077984
# 2013    0.085887
# 2014    0.000180
# Name: オリーブオイル, dtype: float64

# %%
df_rate.loc['パクチー'].pct_change()
# Out:
# 1998         NaN
# 1999         inf
# 2000   -0.529229
# 2001   -0.542599
# 2002   -0.750064
# 2003    3.597507
# 2004   -0.267021
# 2005    0.954753
# 2006   -0.072033
# 2007   -0.015781
# 2008   -0.192788
# 2009    0.017978
# 2010    0.051567
# 2011    0.172119
# 2012    0.148461
# 2013    0.090643
# 2014    0.474541
# Name: パクチー, dtype: float64

# %%
print(df_rate.loc['塩麹'])
# Out:
# 1998    0.000000
# 1999    0.000000
# 2000    0.000000
# 2001    0.000000
# 2002    0.000000
# 2003    0.000000
# 2004    0.000000
# 2005    0.000000
# 2006    0.000000
# 2007    0.000000
# 2008    0.000048
# 2009    0.000798
# 2010    0.000346
# 2011    0.002203
# 2012    0.036233
# 2013    0.013896
# 2014    0.008923
# Name: 塩麹, dtype: float64

# %%
df_test = (df_rate_change > 3)
df_test.any(axis=1)
# Out:
# 砂糖                        False
# 塩                         False
# 水                         False
# 卵                         False
# 醤油                        False
# 酒                         False
# 塩コショウ                      True
# 牛乳                        False
# バター                       False
# 玉ネギ                       False
# ミリン                       False
# ゴマ油                       False
# ニンニク                      False
# マヨネーズ                     False
# オリーブオイル                   False
# ショウユ                       True
# NaN                        True
# サラダ油                       True
# 薄力粉                        True
# 片栗粉                       False
# 小麦粉                       False
# 人参                         True
# ニンジン                      False
# ジャガイモ                     False
# 生クリーム                     False
# 酢                         False
# キャベツ                      False
# キュウリ                      False
# レモン汁                      False
# ...
